# %% [markdown]
# # 튜플 자료형
#
# 튜플과 리스트는 비슷한 역할을 한다. 가장 큰 차이점은 요소를 변화시킬 수 있는지이다. 리스트의 요소는 프로그램 실행중에 변화가 가능하지만 튜플은 변경이 불가능하다. 그래서 튜플은 insert, remove와 같은 내장함수가 없다. 실제 튜플의 요소를 삭제하거나 변경하려고 하면 에러가 발생한다.
#
# 그런데 튜플을 사용하는 이유는 메모리 용량을 아끼고 퍼포먼스 향상을 위해 도움이 되기 때문이다. 실제로 튜플이 리스트보다 빠르다.

# %% [markdown]
# ## 1. 튜플생성

# %%
a = ()
b = (1,2,3)
c = ('Life','is','too short')

# %% [markdown]
# ## 2. 튜플 인덱스

# %%
a = ((0,1,2),
     (3,4,5),
     (6,7,8))

# %% [markdown]
# 문제. a[0][0] 의 값은 얼마인가?

# %% [markdown]
# ## 3. 튜플 슬라이싱

# %% [markdown]
# 투플 슬라이싱은 리스트의 일정구간을 잘라서 가져온다.

# %%
a = [1,2,3,4,5]
# a[0:5]는?
a[:5]
# Out:
# [1, 2, 3, 4, 5]

# %% [markdown]
# ## 4. 튜플 연산

# %%
# 튜플에서 특정 값의 인덱스 구하기

a = (1,2,'a', 'b', 3,4,5)
a.index(3)
# Out:
# 4

# %%
# 특정값의 개수 구하기

a = (1,2,2,3,3,3,3,4)
a.count(3)
# Out:
# 4

# %%
# 값이 있는지 확인하기

a = (1,2,3)
3 in a
# Out:
# True

# %%
a = (3,2,45,5,4)
for i in a:
    print(i, end =' ')
# Out:
# 3 2 45 5 4

# %% [markdown]
# ## 5. zip 사용하기

# %%
x, y = ('a','b') # unpack
z = x, y # tuple pack
print(z)
# Out:
# ('a', 'b')

# %%
A = ['SN1111', 'SN1112', 'SN1113']
B = ['COT', 'COT', 'CNT']

for item in zip(A,B):
    print(item)
# Out:
# ('SN1111', 'COT')
# ('SN1112', 'COT')
# ('SN1113', 'CNT')

# %%
for i in range(3):
  print(A[i],B[i])
# Out:
# SN1111 COT
# SN1112 COT
# SN1113 CNT

# %%
A
# Out:
# ['SN1111', 'SN1112', 'SN1113']

# %%
B
# Out:
# ['COT', 'COT', 'CNT']

# %%
a = {'aaa':'111','bbb':'222', 'ccc':'333'}
# bbb를 검색했을 때 222를 찾는 전화번호부 프로그램을 작성하시오.

def findstr(key):
  return a[key]
   
findstr('bbb')
# Out:
# '222'

# %%
for sn, shiptype in zip(A,B):
    print(sn, shiptype)
# Out:
# SN1111 COT
# SN1112 COT
# SN1113 CNT

# %%
x = {'a':10,'b':20,'c':30, 'd':40}

# 1. x를 이용해서 10, 20, 30, 40 이 출력되도록 프로그램을 짜보세요
for i in x.keys():
  print(item)

findkey
# 2. x를 이용해서 a, b, c, d이 출력되도록 프로그램을 짜보세요
for i in x.values():
  print(item)

# 3. x를 이용해서 (a, 10), (b, 20), ...프로그램을 짜보세요
for i in x.items():
  print(item)

# %%
a = ["김","김","이","이","이","박"]
# b = set(list(a))
# b

# %%
# for item in a:
#   b[item] = item
# # list(b.keys())

# %%
a = [3, 5, 7, 5.5, 8, 10]
# 평균 = sum /n
# 표준편차 = sum((값 - 평균) ^ 2)/n
avg = 0
total = 0
for i in a:
  total += i
  avg = total / 6
avg
# Out:
# 6.416666666666667

# %%
mean = sum(a) / len(a)
n = len(a)
var = 0
for i in a:
  var += (mean -i)**2
var /= n

stats = {"평균": mean, "분산": var}
stats
# Out:
# {'평균': 6.416666666666667, '분산': 5.034722222222222}

# %%
import numpy as np
print("평균", np.mean(a))
print("분산", np.var(a))
# Out:
# 평균 6.416666666666667
# 분산 5.034722222222222

# %%
x=['SN1111', 'COT']

# %%
x1, x2 = x

# %%
x1
# Out:
# 'SN1111'

# %%
x2
# Out:
# 'COT'

# %%
#tuple은 update가 안됨
A = ['SN1111', 'SN1112', 'SN1113']
A[0]
# Out:
# 'SN1111'

# %%
A[0]='TEST'

# %%
A
# Out:
# ['TEST', 'SN1112', 'SN1113']
